# %% [markdown]
# # A Teaser Example

# %%
import numpy as np
import jax
import jax.numpy as jnp
import flax.linen
import optax

import matplotlib
matplotlib.style.use('bmh')
import matplotlib.pyplot as plt

# %% [markdown]
# ## Supervised learning

# %%
x = np.linspace(0, 10, 101)
plt.plot(x, np.sin(x**2-2)/2)
